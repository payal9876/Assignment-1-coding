# %% [raw]
# 1.Write a Python program to print 'hello python'

# %%
print("Hello python")
# Out:
# Hello python

# %% [raw]
# 2.Write a Python program to do arithmetical operations addition and division.?

# %%
'this code will do addition and division'
a=10
b=5
print(a+b)
print(a/b)
# Out:
# 15
# 2.0

# %% [raw]
# 3.Write a Python program to find the area of a triangle? c

# %%
'this code will find area of triangle'
a=float(input('enter first side'))
b=float (input('enter second side'))
c=float(input('enter third side'))
s=(a+b+c)/2
area=s*(s-a)*(s-b)*(s-c)**0.5
print("the area of triangle is",area)
# Out:
# enter first side1
# enter second side2
# enter third side3
# the area of triangle is 0.0

# %%
4.Write a Python program to swap two variables?

# %%
x1=input('enter your x1')
x2=input('enter your x2')
x1,x2=x2,x1
print('the value of x1 after swapping is' x1 )
print('the value of x2 after swapping is' x2 )

# %%
5.Write a Python program to generate a random number?

# %%
import random
a=int(input('enter a lower value'))
b=int(input('enter a upper value'))
print(random.randint(a,b))
# Out:
# enter a lower value2
# enter a upper value4
# 2
